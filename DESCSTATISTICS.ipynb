# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([0,2])
ypoints=np.array([0,100])
plt.plot(xpoints,ypoints)
plt.show()

# %%
plt.plot([5,200],[5,200],"--")
plt.show()

# %%
x=[1,2,3,4,5]
y=[10,20,30,40,50]
plt.scatter(x,y)
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import matplotlib.pyplot as plt
ypoints=np.array([3,8,1,10])
plt.plot(ypoints,marker="o",mec="b",color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,2,6,8])
ypoints=np.array([3,8,1,10])
plt.plot(xpoints,ypoints,"--")
plt.show()

# %%
ypoints=np.array([3,8,1,10,5,7])
plt.plot(ypoints,marker="*",mec="b",color='r',linewidth="10")
plt.show()

# %%
import matplotlib.pyplot as plt
country=['usa','india','goa','uk','france']
GDP_Per_Capita=[48000,38000,500000,45000,440000]
plt.bar(country,GDP_Per_Capita)
plt.title('Country vs GDP_Per_Capita')
plt.xlabel('country')
plt.ylabel('GDP Per Capita')
plt.show()

# %%
plt.barh(country,GDP_Per_Capita)
plt.show()

# %%
plt.bar(country,GDP_Per_Capita,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
numbers=[0.1,1,1.5,2,4,5.5,6,8,9]
plt.hist(numbers,bins=5)
plt.xlabel("Numbers")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
numbers=[0.1,1,1.5,2,4,5.5,6,8,9]
plt.hist(numbers)
plt.xlabel("Numbers")
plt.ylabel("Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,50,15])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,5,10,15])
y=np.array([0,5,10,15])
x1=np.array([15,10,5,0])
y1=np.array([0,5,10,15])
plt.subplot(2,1,2)
plt.subplot(1,2,1)
plt.plot(y,x,x1,y1)

# %%
import matplotlib.pyplot as plt
import numpy as np
y=np.array([35,50,15])
plt.pie(y)
plt.show()

# %%
y=np.array([35,50,15])
co=["r","b","y"]
plt.pie(y,colors=co,labels=("dsp","cd","wt"))
plt.show()

# %%
y=np.array([35,50,15])
plt.legend(title="subject")
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.plot(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([0,1,2,3])
y=np.array([10,20,30,40])
plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1,1,3,3,1,3,3,1,3,1])
y=np.array([3,1,1,3,3,1,3,1,1,3])
plt.subplot(1,2,1)
plt.plot(x,y,marker='o')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([2,5,5])
y=np.array([2,2,4])
plt.subplot(1,2,1)
plt.plot(x,y)

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("Line plot")
x=np.array([1,1,3,3,1,3,3,1,3,1])
y=np.array([3,1,1,3,3,1,3,1,1,3])
plt.subplot(1,2,1)
plt.show(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8612/2623301891.py in <module>
#       5 y=np.array([3,1,1,3,3,1,3,1,1,3])
#       6 plt.subplot(1,2,1)
# ----> 7 plt.show(x,y)
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     376     """
#     377     _warn_if_gui_out_of_main_thread()
# --> 378     return _backend_mod.show(*args, **kwargs)
#     379
#     380
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      47         # only call close('all') if any to close
#      48         # close triggers gc.collect, which can be slow
# ---> 49         if close and Gcf.get_all_fig_managers():
#      50             matplotlib.pyplot.close('all')
#      51
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title=("lineplot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([3,3,5,5,4,5,3,4,3,5])
ypoints=np.array([3,5,5,3,4,5,5,4,3,3])
plt.plot(xpoints,ypoints,marker="o",mec="b",color="red")
plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.title("lineplot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
xpoints=np.array([2,2,3,4,2,4,4,2,3.75,3.75,3.5,3.5,3.25,3.25,3,3,2.75,2.75,2.5,2.5,2,25,2.25,2,2.5,3.5])
ypoints=np.array([2,4,5,4,4,4,2,2,2,4,4,2,2,2,4,4,2,2,4,4,2,2,4,4,2,2,4,4,4.5,4.5])
plt.plot(xpoints,ypoints,marker="o",mec="b",color="red")
plt.plot(xpoints,ypoints)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7984/3382349327.py in <module>
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 plt.title("lineplot")
#       4 plt.xlabel("x-axis")
#       5 plt.ylabel("y-axis")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # graphs data representation

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,30,4,50]
y=[12,13,14,15,6]
plt.scatter(x,y,Linewidth=20,color='r')
plt.show()
# Out:
# C:\Users\Ammani\AppData\Local\Temp/ipykernel_8548/1724945892.py:5: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.scatter(x,y,Linewidth=20,color='r')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,3,40,50]
y=[12,3,14,15,16]
plt.scatter(x,y,s=100,marker='^')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,30,4,50]
y=[12,13,4,15,16]
colors=['red','yellow','blue','green','orange']
plt.scatter(x,y,c=colors,s=1000)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,2,30,4,50]
y=[4,9,6,7,4]
size=['100','200','300','400','500']
plt.scatter(x,y,s=size)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8548/2790391100.py in <module>
#       4 y=[4,9,6,7,4]
#       5 size=['100','200','300','400','500']
# ----> 6 plt.scatter(x,y,s=size)
#       7 plt.show()
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3066         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    3067         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 3068     __ret = gca().scatter(
#    3069         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    3070         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
plt.scatter(x,y,color='r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
plt.scatter(x,y,s=100,alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
plt.scatter(x,y,s=z*1000,alpha=0.4,color='y')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.rand(40)
y=np.random.rand(40)
z=np.random.rand(40)
plt.scatter(x,y,s=100,alpha=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data=[10,20,30,40,50]
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1=[10,20,30,40,50]
data2=[12,14,17,19,20]
plt.boxplot(data1,data2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data1=[10,20,30,40,50]
data2=[4,9,12,16,20]
data=(data1,data2)
plt.boxplot(data)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.DataFrame(np.random.rand(10,5)*1000,columns=['A','B','C','D','E'])
df.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #practox

# %% [raw]
# # p

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1.8,2.8,3.7,4.8])
y=np.array([1.8,4.6,4.5,1.5])
plt.plot(x,y,marker='.',label="data data",color='y',linestyle="--",linewidth="10",markerfacecolor="k",markersize="20",mec="k")
plt.legend(loc="lower right")
plt.title("Lineplot")
plt.xlabel("x vales")
plt.ylabel("y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([1.8,2.8,3.7,4.8])
y=np.array([1.8,4.6,4.5,1.5])
plt.plot(x,marker='.',label="data data",color='y',linestyle="--",linewidth="10",markerfacecolor="k",markersize="20",mec="k")
plt.plot(y)
plt.legend(loc="lower right")
plt.grid(axis='y')
plt.title("Lineplot")
plt.xlabel("x vales")
plt.ylabel("y values")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([0,1,2,3])
y=np.array([3,8,1,10])
plt.subplot(1,2,1)
plt.plot(x,y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,20,30,50,60])
labels=["ds","cd","wt","coa","ior"]
colors=["r","k","y","b","hotpink"]
myexplode=[0.8,0,0,0,0]
plt.pie(x,labels=labels,startangle=90,explode=myexplode,shadow=True,colors=colors,autopct='%1.1f%%')
plt.title("subject data")
plt.legend(loc="upper left",title="subjects")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,30,50])
y=np.array([0,2,4])
plt.xlabel("crime")
plt.ylabel("data")
plt.title("represent histograme")
plt.hist(x,label="data reprsentation")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal([170,10,250])
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,17,18,20,28])
y=np.array([23,12,16,19,20])
plt.barh(x,y,color="y",height=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([12,17,18,20,28])
y=np.array([23,12,16,19,20])
plt.bar(x,y,color="y",width=0.4,label="data")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,15,25,30,35,10])
y=np.mean(x)
print(y)
z=np.median(x)
print(z)
d=np.var(x)
print(d)
c=np.std(x)
print(c)
z=np.max(x)
print(z)
z=min(x)
print(z)
d=np.ptp(x)
print(d)
plt.boxplot(x)
plt.show()
# Out:
# 20.833333333333332
# 20.0
# 95.1388888888889
# 9.753916592266355
# 35
# 10
# 25

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([10,20,30,40,50])
y=np.array([11,18,13,19,15])
colors=['r','b','g','k','y']
plt.scatter(x,y,c=colors,marker="o",s=z*100,linewidth=10,alpha=0.4,)
plt.show()
