# %%
import pandas as pd
df=pd.read_csv("game.csv")
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#no of rows and no of columns
df.shape
# Out:
# (130, 26)

# %%
df.size
# Out:
# 3380

# %%
df[['PLAYER NAME','COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
df.head(10).transpose()
# Out:
#                          0             1            2          3  \
# Sl.NO.                   1             2            3          4
# PLAYER NAME    Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R
# AGE                      2             2            2          1
# COUNTRY                 SA           BAN          IND        IND
# TEAM                  KXIP           RCB          KKR        CSK
# PLAYING ROLE    Allrounder        Bowler       Bowler     Bowler
# T-RUNS                   0           214          571        284
# T-WKTS                   0            18           58         31
# ODI-RUNS-S               0           657         1269        241
# ODI-SR-B               0.0         71.41        80.62      84.56
# ODI-WKTS                 0           185          288         51
# ODI-SR-BL              0.0          37.6         32.9       36.8
# CAPTAINCY EXP            0             0            0          0
# ...

# %%
df.tail(10)
# Out:
#      Sl.NO.     PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 120     121     Vettori, DL    2      NZ    DD+   Allrounder    4486     359
# 121     122  Vinay Kumar, R    2     IND   RCB+       Bowler      11       1
# 122     123       Warne, SK    3     AUS     RR       Bowler    3154     708
# 123     124      Warner, DA    1     AUS     DD      Batsman     483       2
# 124     125       White, CL    2     AUS   RCB+      Batsman     146       5
# 125     126       Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127     Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128    Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129     Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130      Zoysa, DNT    2      SL     DC       Bowler     288      64
#
#      ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sl.NO.         130 non-null    int64
#  1   PLAYER NAME    130 non-null    object
#  2   AGE            130 non-null    int64
#  3   COUNTRY        130 non-null    object
#  4   TEAM           130 non-null    object
#  5   PLAYING ROLE   130 non-null    object
#  6   T-RUNS         130 non-null    int64
#  7   T-WKTS         130 non-null    int64
#  8   ODI-RUNS-S     130 non-null    int64
#  9   ODI-SR-B       130 non-null    float64
#  10  ODI-WKTS       130 non-null    int64
#  11  ODI-SR-BL      130 non-null    float64
#  12  CAPTAINCY EXP  130 non-null    int64
#  13  RUNS-S         130 non-null    int64
#  14  HS             130 non-null    int64
#  15  AVE            130 non-null    float64
#  16  SR-B           130 non-null    float64
# ...

# %%
print(df[70:81])
print(df[100:110])
# Out:
#     Sl.NO.   PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 70      71    Nannes, DP    3     AUS   DD+       Bowler       0       0
# 71      72     Nayar, AM    2     IND   MI+   Allrounder       0       0
# 72      73      Nehra, A    2     IND   DD+       Bowler      77      44
# 73      74    Noffke, AA    2     AUS   RCB   Allrounder       0       0
# 74      75      Ntini, M    2      SA   CSK       Bowler     699     390
# 75      76      Ojha, NV    2     IND   RR+    W. Keeper       0       0
# 76      77      Ojha, PP    1     IND   DC+       Bowler      70      62
# 77      78     Oram, JDP    2      NZ  CSK+   Allrounder    1780      60
# 78      79  Pankaj Singh    2     IND  RCB+       Bowler       0       0
# 79      80     Patel, MM    2     IND   RR+       Bowler      60      35
# 80      81     Patel, PA    2     IND  CSK+    W. Keeper     683       0
#
#     ODI-RUNS-S  ODI-SR-B  ...    SR-B  SIXERS  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df['PLAYER NAME'][0:5]
# Out:
# 0     Abdulla, YA
# 1    Abdur Razzak
# 2     Agarkar, AB
# 3       Ashwin, R
# 4    Badrinath, S
# Name: PLAYER NAME, dtype: object

# %%
df[['PLAYER NAME','COUNTRY']][0:5]
# Out:
#     PLAYER NAME COUNTRY
# 0   Abdulla, YA      SA
# 1  Abdur Razzak     BAN
# 2   Agarkar, AB     IND
# 3     Ashwin, R     IND
# 4  Badrinath, S     IND

# %%
df.iloc[5:11,1:4]
# Out:
#       PLAYER NAME  AGE COUNTRY
# 5      Bailey, GJ    2     AUS
# 6       Balaji, L    2     IND
# 7   Bollinger, DE    2     AUS
# 8        Botha, J    2      SA
# 9     Boucher, MV    2      SA
# 10      Bravo, DJ    2      WI

# %%
df.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
df.COUNTRY.value_counts(normalize=True)
# Out:
# IND    0.407692
# AUS    0.169231
# SA     0.123077
# SL     0.092308
# PAK    0.069231
# NZ     0.053846
# WI     0.046154
# ENG    0.023077
# BAN    0.007692
# ZIM    0.007692
# Name: COUNTRY, dtype: float64

# %%
pd.crosstab(df['AGE'],df['PLAYING ROLE'])
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                      4        5       7          0
# 2                     25       21      29         11
# 3                      6       13       8          1

# %%
import pandas as pd
df=pd.read_csv("game.csv")
pd.crosstab(df['COUNTRY'],df['PLAYER NAME'])
# Out:
# PLAYER NAME  Abdulla, YA  Abdur Razzak  Agarkar, AB  Ashwin, R  Badrinath, S  \
# COUNTRY
# AUS                    0             0            0          0             0
# BAN                    0             1            0          0             0
# ENG                    0             0            0          0             0
# IND                    0             0            1          1             1
# NZ                     0             0            0          0             0
# PAK                    0             0            0          0             0
# SA                     1             0            0          0             0
# SL                     0             0            0          0             0
# WI                     0             0            0          0             0
# ZIM                    0             0            0          0             0
#
# PLAYER NAME  Bailey, GJ  Balaji, L  Bollinger, DE  Botha, J  Boucher, MV  ...  \
# ...

# %%
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE')[0:6]
# Out:
#        PLAYER NAME  SOLD PRICE
# 73      Noffke, AA       20000
# 46     Kamran Khan       24000
# 0      Abdulla, YA       50000
# 1     Abdur Razzak       50000
# 118  Van der Merwe       50000
# 5       Bailey, GJ       50000

# %%
import pandas as pd
df=pd.read_csv("game.csv")
df[['PLAYER NAME','SOLD PRICE']].sort_values('SOLD PRICE',ascending=False)[0:6]
# Out:
#        PLAYER NAME  SOLD PRICE
# 93       Sehwag, V     1800000
# 127   Yuvraj Singh     1800000
# 50        Kohli, V     1800000
# 111  Tendulkar, SR     1800000
# 113     Tiwary, SS     1600000
# 83   Pietersen, KP     1550000

# %%
#creat new coloumn
x=df['premium']
print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\a\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'premium'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
x=df['premium']=df['SOLD PRICE']-df['BASE PRICE']
print(x)

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.iloc[0:6,1:3]
# Out:
#     PLAYER NAME  AGE
# 0   Abdulla, YA    2
# 1  Abdur Razzak    2
# 2   Agarkar, AB    2
# 3     Ashwin, R    1
# 4  Badrinath, S    2
# 5    Bailey, GJ    2

# %%
df.COUNTRY.value_counts()
# Out:
# IND    53
# AUS    22
# SA     16
# SL     12
# PAK     9
# NZ      7
# WI      6
# ENG     3
# BAN     1
# ZIM     1
# Name: COUNTRY, dtype: int64

# %%
pd.crosstab(df['AGE'],df['COUNTRY'])
# Out:
# COUNTRY  AUS  BAN  ENG  IND  NZ  PAK  SA  SL  WI  ZIM
# AGE
# 1          2    0    0   13   0    0   0   1   0    0
# 2         10    1    3   35   5    7  11   8   5    1
# 3         10    0    0    5   2    2   5   3   1    0

# %%
df['premium']=df['SOLD PRICE']-df['BASE PRICE']

# %%
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df['Ammani']=df['AGE']-df['SOLD PRICE']
df
# Out:
#      Sl.NO.   PLAYER NAME  AGE COUNTRY   TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# 0         1   Abdulla, YA    2      SA   KXIP   Allrounder       0       0
# 1         2  Abdur Razzak    2     BAN    RCB       Bowler     214      18
# 2         3   Agarkar, AB    2     IND    KKR       Bowler     571      58
# 3         4     Ashwin, R    1     IND    CSK       Bowler     284      31
# 4         5  Badrinath, S    2     IND    CSK      Batsman      63       0
# ..      ...           ...  ...     ...    ...          ...     ...     ...
# 125     126     Yadav, AS    2     IND     DC      Batsman       0       0
# 126     127   Younis Khan    2     PAK     RR      Batsman    6398       7
# 127     128  Yuvraj Singh    2     IND  KXIP+      Batsman    1775       9
# 128     129   Zaheer Khan    2     IND    MI+       Bowler    1114     288
# 129     130    Zoysa, DNT    2      SL     DC       Bowler     288      64
#
# ...

# %%
df.groupby('AGE')['SOLD PRICE'].mean().reset_index()
# Out:
#    AGE     SOLD PRICE
# 0    1  720250.000000
# 1    2  484534.883721
# 2    3  520178.571429

# %%
df.rename(columns={'AGE':'AMMANIN_AGE'},inplace=True)
df.iloc[0:5,1:5]
# Out:
#     PLAYER NAME  AMMANIN_AGE COUNTRY  TEAM
# 0   Abdulla, YA            2      SA  KXIP
# 1  Abdur Razzak            2     BAN   RCB
# 2   Agarkar, AB            2     IND   KKR
# 3     Ashwin, R            1     IND   CSK
# 4  Badrinath, S            2     IND   CSK

# %%
df[df['AMMANIN_AGE']>2][['PLAYER NAME','TEAM']]
# Out:
#          PLAYER NAME  TEAM
# 11    Chanderpaul, S   RCB
# 18        Dravid, RS  RCB+
# 22       Fleming, SP   CSK
# 25       Ganguly, SC  KKR+
# 27         Gibbs, HH    DC
# 28     Gilchrist, AC   DC+
# 32        Hayden, ML   CSK
# 33      Henderson, T    RR
# 35         Hodge, BJ  KKR+
# 38       Hussey, MEK   CSK
# 41    Jayasuriya, ST    MI
# 44        Kallis, JH   RCB
# 49        Katich, SM  KXIP
# 52         Kumble, A   RCB
# 53    Langeveldt, CK  KKR+
# 54       Laxman, VVS   DC+
# 62       McGrath, GD    DD
# 63     Misbah-ul-Haq   RCB
# 69   Muralitharan, M  CSK+
# 70        Nannes, DP   DD+
# 84       Pollock, SM    MI
# 86       Ponting, RT   KKR
# 98     Shoaib Akhtar   KKR
# 107       Styris, SB   DC+
# 108       Symonds, A   DC+
# 111    Tendulkar, SR    MI
# 117      Vaas, WPUJC    DC
# 122        Warne, SK    RR

# %%
df
# Out:
#     COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  \
# 0        SA   Allrounder       0       0           0      0.00         0
# 1       BAN       Bowler     214      18         657     71.41       185
# 2       IND       Bowler     571      58        1269     80.62       288
# 3       IND       Bowler     284      31         241     84.56        51
# 4       IND      Batsman      63       0          79     45.93         0
# ..      ...          ...     ...     ...         ...       ...       ...
# 125     IND      Batsman       0       0           0      0.00         0
# 126     PAK      Batsman    6398       7        6814     75.78         3
# 127     IND      Batsman    1775       9        8051     87.58       109
# 128     IND       Bowler    1114     288         790     73.55       278
# 129      SL       Bowler     288      64         343     95.81       108
#
#      ODI-SR-BL  CAPTAINCY EXP  RUNS-S  ...  RUNS-C  WKTS  AVE-BL   ECON  \
# ...

# %%
df.drop('COUNTRY',inplace=True,axis=1)
df
# Out:
#     PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ODI-SR-BL  \
# 0     Allrounder       0       0           0      0.00         0        0.0
# 1         Bowler     214      18         657     71.41       185       37.6
# 2         Bowler     571      58        1269     80.62       288       32.9
# 3         Bowler     284      31         241     84.56        51       36.8
# 4        Batsman      63       0          79     45.93         0        0.0
# ..           ...     ...     ...         ...       ...       ...        ...
# 125      Batsman       0       0           0      0.00         0        0.0
# 126      Batsman    6398       7        6814     75.78         3       86.6
# 127      Batsman    1775       9        8051     87.58       109       44.3
# 128       Bowler    1114     288         790     73.55       278       35.4
# 129       Bowler     288      64         343     95.81       108       39.4
#
# ...

# %%
df.columns
# Out:
# Index(['PLAYING ROLE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B',
#        'ODI-WKTS', 'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B',
#        'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR',
#        'BASE PRICE', 'SOLD PRICE', 'premium', 'Ammani'],
#       dtype='object')

# %%
import numpy as np
import matplotlib.pyplot as plt
df.barplot(x='AGE',Y='SOLID PRICE')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11000/1155466898.py in <module>
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 df.barplot(x='AGE',Y='SOLID PRICE')
#
# C:\ProgramData\Anaconda3\a\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'barplot'

# %%
plt.hist(df['SOLD PRICE'])
# Out:
# (array([27., 32., 21., 20., 14.,  7.,  0.,  1.,  4.,  4.]),
#  array([  20000.,  198000.,  376000.,  554000.,  732000.,  910000.,
#         1088000., 1266000., 1444000., 1622000., 1800000.]),
#  <BarContainer object of 10 artists>)
