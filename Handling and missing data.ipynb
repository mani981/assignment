# %%
import pandas as pd
df=pd.read_csv('sample.csv')
new_df=df.dropna()
print(new_df)
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 2    c    2.0  12.0      cd    4.0
# 4    e    4.0  13.0     coa    7.0
# 7    g    6.0  16.0     ior    9.0

# %%
#if get the entaire row is repeated in more than1 then the row is removed
df=pd.read_csv('sample.csv')
df
print(df)
print("----")
df.drop_duplicates(keep=False,inplace=True)
print(df)
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    NaN
# 6  NaN    NaN  15.0     NaN    NaN
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0
# ----
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    NaN
# 6  NaN    NaN  15.0     NaN    NaN
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df=pd.read_csv('sample.csv')
df.fillna(130,inplace=True)
df
# Out:
#   name  class    age subject  marks
# 0    a    1.0   10.0      cd    3.0
# 1    b  130.0   11.0     dsp    6.0
# 2    c    2.0   12.0      cd    4.0
# 3    d    3.0  130.0      wt    2.0
# 4    e    4.0   13.0     coa    7.0
# 5    f    5.0   14.0      wt  130.0
# 6  130  130.0   15.0     130  130.0
# 7    g    6.0   16.0     ior    9.0
# 8    h    7.0   17.0     130    6.0

# %%
df=pd.read_csv('sample.csv')
df
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    NaN
# 6  NaN    NaN  15.0     NaN    NaN
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df=pd.read_csv('sample.csv')
df["age"].fillna(130,inplace=True)
df
# Out:
#   name  class    age subject  marks
# 0    a    1.0   10.0      cd    3.0
# 1    b    NaN   11.0     dsp    6.0
# 2    c    2.0   12.0      cd    4.0
# 3    d    3.0  130.0      wt    2.0
# 4    e    4.0   13.0     coa    7.0
# 5    f    5.0   14.0      wt    NaN
# 6  NaN    NaN   15.0     NaN    NaN
# 7    g    6.0   16.0     ior    9.0
# 8    h    7.0   17.0     NaN    6.0

# %%
import pandas as pd
df=pd.read_csv('sample.csv')
df.dropna(subset=['marks'],inplace=True)
df
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df.loc[3,'age']=45
df
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0  45.0      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0  45.0      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df=pd.read_csv('sample.csv')
df
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    NaN
# 6  NaN    NaN  15.0     NaN    NaN
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
df.dropna()
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 2    c    2.0  12.0      cd    4.0
# 4    e    4.0  13.0     coa    7.0
# 7    g    6.0  16.0     ior    9.0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5692/979824394.py in <module>
#       1 df=pd.read_csv('sample.csv')
# ----> 2 df.drop(["name"])
#       3 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['name'] not found in axis"

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5692/2237671880.py in <module>
# ----> 1 df=drop.loc[3,'age']
#       2 df
#
# NameError: name 'drop' is not defined

# %%
x=(2,4,5,6,2)
x.drop_duplicates(inplace=True)
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6888/1539398678.py in <module>
#       1 x=(2,4,5,6,2)
# ----> 2 x.drop_duplicates(inplace=True)
#       3 print(x)
#
# AttributeError: 'tuple' object has no attribute 'drop_duplicates'

# %% [markdown]
# # practice

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
print(df)
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    NaN  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   NaN      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    NaN
# 6  NaN    NaN  15.0     NaN    NaN
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0     NaN    6.0

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
print(df.isnull())
# Out:
#     name  class    age  subject  marks
# 0  False  False  False    False  False
# 1  False   True  False    False  False
# 2  False  False  False    False  False
# 3  False  False   True    False  False
# 4  False  False  False    False  False
# 5  False  False  False    False   True
# 6   True   True  False     True   True
# 7  False  False  False    False  False
# 8  False  False  False     True  False

# %%
df.isnull().sum()
# Out:
# name       1
# class      2
# age        1
# subject    2
# marks      2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 8

# %%
df=df.fillna(value=2)
print(df)
# Out:
#   name  class   age subject  marks
# 0    a    1.0  10.0      cd    3.0
# 1    b    2.0  11.0     dsp    6.0
# 2    c    2.0  12.0      cd    4.0
# 3    d    3.0   2.0      wt    2.0
# 4    e    4.0  13.0     coa    7.0
# 5    f    5.0  14.0      wt    2.0
# 6    2    2.0  15.0       2    2.0
# 7    g    6.0  16.0     ior    9.0
# 8    h    7.0  17.0       2    6.0

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
df.fillna("ammu",inplace=True)
print(df)
# Out:
#    name class   age subject marks
# 0     a   1.0  10.0      cd   3.0
# 1     b  ammu  11.0     dsp   6.0
# 2     c   2.0  12.0      cd   4.0
# 3     d   3.0  ammu      wt   2.0
# 4     e   4.0  13.0     coa   7.0
# 5     f   5.0  14.0      wt  ammu
# 6  ammu  ammu  15.0    ammu  ammu
# 7     g   6.0  16.0     ior   9.0
# 8     h   7.0  17.0    ammu   6.0

# %%
df=df.fillna(method='pad')
df
# Out:
#    name class   age subject marks
# 0     a   1.0  10.0      cd   3.0
# 1     b  ammu  11.0     dsp   6.0
# 2     c   2.0  12.0      cd   4.0
# 3     d   3.0  ammu      wt   2.0
# 4     e   4.0  13.0     coa   7.0
# 5     f   5.0  14.0      wt  ammu
# 6  ammu  ammu  15.0    ammu  ammu
# 7     g   6.0  16.0     ior   9.0
# 8     h   7.0  17.0    ammu   6.0

# %%
df.fillna(method='bfill',axis=1)
df
# Out:
#    name class   age subject marks
# 0     a   1.0  10.0      cd   3.0
# 1     b  ammu  11.0     dsp   6.0
# 2     c   2.0  12.0      cd   4.0
# 3     d   3.0  ammu      wt   2.0
# 4     e   4.0  13.0     coa   7.0
# 5     f   5.0  14.0      wt  ammu
# 6  ammu  ammu  15.0    ammu  ammu
# 7     g   6.0  16.0     ior   9.0
# 8     h   7.0  17.0    ammu   6.0

# %%
df
# Out:
#    name class   age subject marks
# 0     a   1.0  10.0      cd   3.0
# 1     b  ammu  11.0     dsp   6.0
# 2     c   2.0  12.0      cd   4.0
# 3     d   3.0  ammu      wt   2.0
# 4     e   4.0  13.0     coa   7.0
# 5     f   5.0  14.0      wt  ammu
# 6  ammu  ammu  15.0    ammu  ammu
# 7     g   6.0  16.0     ior   9.0
# 8     h   7.0  17.0    ammu   6.0

# %%
import pandas as pd
df=pd.read_csv("sample.csv")
x=df["age"].max()
print(x)
# Out:
# 17.0

# %%
x=df["age"].min()
print(x)
# Out:
# 10.0
