# %%
import matplotlib.pyplot as plt
import pandas as pd
x=[10,20,30,40,50]
y=[22,23,24,25,26]
plt.plot(x,y,marker='o',color='r',linewidth='3',linestyle='--',markerfacecolor='k',label='profit unit')
plt.legend(loc='lower right')
plt.xlabel("data")
plt.ylabel("data")
plt.title("sample")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
x=[10,20,30,40,50]
labels=['a','b','c','d','e']
plt.pie(x,autopct='%1.1f%%')
plt.legend('lower left')
plt.show()
